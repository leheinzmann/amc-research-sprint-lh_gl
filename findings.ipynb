# %% [markdown]
# # Findings

# %% [markdown]
# ## Weapons and ammo:
#
# Columns ban_possession and ban_disposal are filled with zeros.
# No treaty bans the possession nor the disposal of the weapons in the database.
# There is no correlation between the no-ban in possession/disposal and other variables.
# It seems strange that there are no exceptions.
#
# API 36 is not taken into consideration.
