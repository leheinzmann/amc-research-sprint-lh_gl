# %% [markdown]
# # Exploratory Data Analysis
# This notebook is used to explore the initial dataset and see what we have to work with

# %%
import pandas as pd
pd.options.display.max_columns = None

data_df = pd.read_csv('data/amcdata_weapons_facilities_V2.csv', encoding='latin-1')

# %%
data_groupby_df = data_df.groupby(['ban_development']).count()
data_groupby_df.head(5)
# Out:
#                  agreement_id  Item_letter  Item_number  item_type  item  \
# ban_development
# 0                         400          329          329        397   382
# 1                          34           22           22         34    34
#
#                  facility  weapon_item_definition  c_weapon_item_definition  \
# ban_development
# 0                      19                     243                       106
# 1                       0                      18                         8
#
#                  subcategory  subcategory_main  summary_category  \
# ban_development
# 0                          0                 0               319
# 1                          0                 0                30
#
#                  c_ban_development  ban_development_execution_type  \
# ban_development
# 0                                0                             400
# 1                               34                              34
#
# ...

# %%
data_df.head(5)
# Out:
#    agreement_id Item_letter  Item_number  item_type  \
# 0            40           A          1.0        1.0
# 1            50           A          1.0        1.0
# 2            50           B          2.0        3.0
# 3            50         NaN          NaN        1.0
# 4            50           C          3.0        1.0
#
#                                    item facility weapon_item_definition  \
# 0                       Weapons General      NaN                     99
# 1                       Nuclear Weapons      NaN                     99
# 2                     Radioactive Waste      NaN                     99
# 3  Summary Category A (Nuclear Weapons)      NaN                    NaN
# 4                       Weapons General      NaN                    NaN
#
#   c_weapon_item_definition  subcategory  subcategory_main  summary_category  \
# 0                      NaN          NaN               NaN               0.0
# ...
